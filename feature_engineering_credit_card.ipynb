# %% [markdown]
# ##Step 2: Data Collection

# %% [markdown]
# ###Import Necessary Libraries

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel,RFE
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ###Import Dataset

# %%
credit_card_data = pd.read_csv('credit_card_clean.csv')
credit_card_data
# Out:
#           ID  LIMIT_BAL     SEX   EDUCATION MARRIAGE  AGE  PAY_1  PAY_2  \
# 0          1    20000.0  female  university  married   24      2      2
# 1          2   120000.0  female  university   single   26     -1      2
# 2          3    90000.0  female  university   single   34      0      0
# 3          4    50000.0  female  university  married   37      0      0
# 4          5    50000.0    male  university  married   57     -1      0
# ...      ...        ...     ...         ...      ...  ...    ...    ...
# 29995  29996   220000.0    male  highschool  married   39      0      0
# 29996  29997   150000.0    male  highschool   single   43     -1     -1
# 29997  29998    30000.0    male  university   single   37      4      3
# 29998  29999    80000.0    male  highschool  married   41      1     -1
# 29999  30000    50000.0    male  university  married   46      0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %% [markdown]
# ##Step 3: Data Understanding

# %% [markdown]
# ###Perform initial investigation

# %%
credit_card_data.shape
# Out:
# (30000, 25)

# %%
credit_card_data.isna().sum()
# Out:
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_1        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# DEFAULT      0
# dtype: int64

# %%
credit_card_data.dtypes
# Out:
# ID             int64
# LIMIT_BAL    float64
# SEX           object
# EDUCATION     object
# MARRIAGE      object
# AGE            int64
# PAY_1          int64
# PAY_2          int64
# PAY_3          int64
# PAY_4          int64
# PAY_5          int64
# PAY_6          int64
# BILL_AMT1    float64
# BILL_AMT2    float64
# BILL_AMT3    float64
# BILL_AMT4    float64
# BILL_AMT5    float64
# BILL_AMT6    float64
# PAY_AMT1     float64
# PAY_AMT2     float64
# PAY_AMT3     float64
# PAY_AMT4     float64
# PAY_AMT5     float64
# PAY_AMT6     float64
# DEFAULT        int64
# dtype: object

# %%
credit_card_data.describe(include='all')
# Out:
#              LIMIT_BAL     SEX   EDUCATION MARRIAGE           AGE  \
# count     30000.000000   30000       30000    30000  30000.000000
# unique             NaN       2           4        3           NaN
# top                NaN  female  university   single           NaN
# freq               NaN   18112       14030    15964           NaN
# mean     167484.322667     NaN         NaN      NaN     35.485500
# std      129747.661567     NaN         NaN      NaN      9.217904
# min       10000.000000     NaN         NaN      NaN     21.000000
# 25%       50000.000000     NaN         NaN      NaN     28.000000
# 50%      140000.000000     NaN         NaN      NaN     34.000000
# 75%      240000.000000     NaN         NaN      NaN     41.000000
# max     1000000.000000     NaN         NaN      NaN     79.000000
#
#                PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count   30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# ...

# %% [markdown]
# ##Step 4: Data Preparation

# %%
del credit_card_data['ID']

# %%
le = LabelEncoder()
credit_card_data['SEX'] = le.fit_transform(credit_card_data['SEX'])
credit_card_data['EDUCATION'] = le.fit_transform(credit_card_data['EDUCATION'])
credit_card_data['MARRIAGE'] = le.fit_transform(credit_card_data['MARRIAGE'])

# %%
credit_card_data.dtypes
# Out:
# LIMIT_BAL    float64
# SEX            int64
# EDUCATION      int64
# MARRIAGE       int64
# AGE            int64
# PAY_1          int64
# PAY_2          int64
# PAY_3          int64
# PAY_4          int64
# PAY_5          int64
# PAY_6          int64
# BILL_AMT1    float64
# BILL_AMT2    float64
# BILL_AMT3    float64
# BILL_AMT4    float64
# BILL_AMT5    float64
# BILL_AMT6    float64
# PAY_AMT1     float64
# PAY_AMT2     float64
# PAY_AMT3     float64
# PAY_AMT4     float64
# PAY_AMT5     float64
# PAY_AMT6     float64
# DEFAULT        int64
# dtype: object

# %%
X = credit_card_data.drop(columns='DEFAULT')
X
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0        20000.0    0          3         0   24      2      2     -1     -1
# 1       120000.0    0          3         2   26     -1      2      0      0
# 2        90000.0    0          3         2   34      0      0      0      0
# 3        50000.0    0          3         0   37      0      0      0      0
# 4        50000.0    1          3         0   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   220000.0    1          1         0   39      0      0      0      0
# 29996   150000.0    1          1         2   43     -1     -1     -1     -1
# 29997    30000.0    1          3         2   37      4      3      2     -1
# 29998    80000.0    1          1         0   41      1     -1      0      0
# 29999    50000.0    1          3         0   46      0      0      0      0
#
# ...

# %%
y = credit_card_data.DEFAULT
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: DEFAULT, Length: 30000, dtype: int64

# %% [markdown]
# ## Step 5: Model Building

# %% [markdown]
# ###Train Test Split

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2,random_state=13,shuffle=True,stratify=y)

# %%
rf_model = RandomForestClassifier()

# %% [markdown]
# ##Step 6: Model Training

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ##Step 7: Model Testing

# %%
y_pred_train = rf_model.predict(X_train)
y_pred_test = rf_model.predict(X_test)

# %% [markdown]
# ##Step 8: Model Evaluation

# %%
print('Accuracy Score:',round(accuracy_score(y_test,y_pred_test),4))
print('Precision Score:',round(precision_score(y_test,y_pred_test),4))
print('Recall Score:',round(recall_score(y_test,y_pred_test),4))
print('Confusion Matrix:\n',confusion_matrix(y_test,y_pred_test))
# Out:
# Accuracy Score: 0.805
# Precision Score: 0.6065
# Recall Score: 0.3369
# Confusion Matrix:
#  [[4383  290]
#  [ 880  447]]

# %% [markdown]
# ### Technique 1 for Feature Selection

# %%
def runRandomForestClassifier(X_train,X_test,y_train,y_test):

  rf_model = RandomForestClassifier(random_state=13)
  rf_model.fit(X_train,y_train)
  y_pred = rf_model.predict(X_test)
  print('Accuracy_score:',round(accuracy_score(y_test,y_pred),4))
  print('Precision_score:',round(precision_score(y_test,y_pred),4))
  print('Recall_score:',round(recall_score(y_test,y_pred),4))
  print('Confusion Matrix:\n',confusion_matrix(y_test,y_pred))

# %%
sf_model = SelectFromModel(estimator=RandomForestClassifier(),max_features=17)
sf_model.fit(X_train,y_train)
print(sf_model.get_support())
print(X.columns[sf_model.get_support()])
print(len(X.columns[sf_model.get_support()]))
X_train_sf_model = sf_model.transform(X_train)
X_test_sf_model = sf_model.transform(X_test)
# Out:
# [ True False False False  True  True  True False False False False  True
#   True  True  True  True  True  True  True  True False False  True]
# Index(['LIMIT_BAL', 'AGE', 'PAY_1', 'PAY_2', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT6'],
#       dtype='object')
# 14

# %%
runRandomForestClassifier(X_train,X_test,y_train,y_test)##23 features
# Out:
# Accuracy_score: 0.808
# Precision_score: 0.6194
# Recall_score: 0.3421
# Confusion Matrix:
#  [[4394  279]
#  [ 873  454]]

# %%
runRandomForestClassifier(X_train_sf_model,X_test_sf_model,y_train,y_test)##17 Features
# Out:
# Accuracy_score: 0.8057
# Precision_score: 0.6155
# Recall_score: 0.3233
# Confusion Matrix:
#  [[4405  268]
#  [ 898  429]]

# %% [markdown]
# ###Technique 2 For Feature Selection

# %%
rfe_model = RFE(estimator=RandomForestClassifier(),n_features_to_select=15)
rfe_model.fit(X_train,y_train)
print(rfe_model.get_support())
print(X.columns[rfe_model.get_support()])
print(len(X.columns[rfe_model.get_support()]))
X_train_rfe_model = rfe_model.transform(X_train)
X_test_rfe_model = rfe_model.transform(X_test)
# Out:
# [ True False False False  True  True  True False False False False  True
#   True  True  True  True  True  True  True  True  True False  True]
# Index(['LIMIT_BAL', 'AGE', 'PAY_1', 'PAY_2', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT6'],
#       dtype='object')
# 15

# %%
runRandomForestClassifier(X_train,X_test,y_train,y_test)##23 features
# Out:
# Accuracy_score: 0.807
# Precision_score: 0.6147
# Recall_score: 0.3414
# Confusion Matrix:
#  [[4389  284]
#  [ 874  453]]

# %%
runRandomForestClassifier(X_train_rfe_model,X_test_rfe_model,y_train,y_test)##15features
# Out:
# Accuracy_score: 0.8087
# Precision_score: 0.6262
# Recall_score: 0.3346
# Confusion Matrix:
#  [[4408  265]
#  [ 883  444]]

# %% [markdown]
# ### Providing Important features of GradientBoosting within RandomForest

# %%
rfe_model_1 = RFE(estimator=GradientBoostingClassifier(),n_features_to_select=None)
rfe_model_1.fit(X_train,y_train)
print(rfe_model_1.get_support())
print(X.columns[rfe_model_1.get_support()])
print(len(X.columns[rfe_model_1.get_support()]))
X_train_rfe_model_1 = rfe_model_1.transform(X_train)
X_test_rfe_model_1 = rfe_model_1.transform(X_test)
# Out:
# [ True False False False False  True  True  True  True  True False  True
#   True False False False False  True  True  True False False False]
# Index(['LIMIT_BAL', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'BILL_AMT1',
#        'BILL_AMT2', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3'],
#       dtype='object')
# 11

# %%
runRandomForestClassifier(X_train,X_test,y_train,y_test)##23 features
# Out:
# Accuracy_score: 0.8058
# Precision_score: 0.6104
# Recall_score: 0.3376
# Confusion Matrix:
#  [[4387  286]
#  [ 879  448]]

# %%
runRandomForestClassifier(X_train_rfe_model_1,X_test_rfe_model_1,y_train,y_test)##23 features
# Out:
# Accuracy_score: 0.8067
# Precision_score: 0.6118
# Recall_score: 0.3444
# Confusion Matrix:
#  [[4383  290]
#  [ 870  457]]

# %% [markdown]
# ###Finding the optimal number of features

# %%
def runRandomForestClassifier(X_train,X_test,y_train,y_test):

  rf_model = RandomForestClassifier(random_state=13)
  rf_model.fit(X_train,y_train)
  y_pred = rf_model.predict(X_test)
  print('Accuracy_score:',round(accuracy_score(y_test,y_pred),4))
  print('Precision_score:',round(precision_score(y_test,y_pred),4))
  print('Recall_score:',round(recall_score(y_test,y_pred),4))
  print('Confusion Matrix:\n',confusion_matrix(y_test,y_pred))

# %%
for i in range(1,24):
  rfe_model = RFE(estimator=GradientBoostingClassifier(),n_features_to_select=i)
  rfe_model.fit(X_train,y_train)
  X_train_rfe_model = rfe_model.transform(X_train)
  X_test_rfe_model = rfe_model.transform(X_test)
  print('Selected Features:',i)
  runRandomForestClassifier(X_train_rfe_model,X_test_rfe_model,y_train,y_test)
  print('------------------------------')
# Out:
# Selected Features: 1
# Accuracy_score: 0.8153
# Precision_score: 0.6898
# Recall_score: 0.2999
# Confusion Matrix:
#  [[4494  179]
#  [ 929  398]]
# ------------------------------
# Selected Features: 2
# Accuracy_score: 0.8152
# Precision_score: 0.6873
# Recall_score: 0.3014
# Confusion Matrix:
#  [[4491  182]
#  [ 927  400]]
# ------------------------------
# Selected Features: 3
# Accuracy_score: 0.73
# Precision_score: 0.378
# Recall_score: 0.3421
# Confusion Matrix:
#  [[3926  747]
#  [ 873  454]]
# ------------------------------
# Selected Features: 4
# Accuracy_score: 0.7743
# Precision_score: 0.4848
# Recall_score: 0.3248
# Confusion Matrix:
#  [[4215  458]
#  [ 896  431]]
# ------------------------------
# Selected Features: 5
# Accuracy_score: 0.7783
# Precision_score: 0.4983
# Recall_score: 0.3346
# Confusion Matrix:
#  [[4226  447]
#  [ 883  444]]
# ------------------------------
# Selected Features: 6
# Accuracy_score: 0.7808
# Precision_score: 0.5066
# ...
